# %%
import pandas as pd 
df = pd.read_csv('MASC_final_data.csv') 
df.head()
# Out:
#                 ID                                               Text Pronoun  \
# 0     validation-7  Lieutenant General Weber Pasha wanted Faik Pas...      He
# 1         test-245  The project was greenlit by Walt Disney Pictur...      he
# 2  development-478  After successfully organizing the murder of th...      He
# 3         test-406  In 617, the secretary general of Wuyang Comman...      he
# 4         test-903  Roosevelt also produced the film Pot o' Gold a...     his
#
#    Pronoun-offset              A  A-offset  A-coref           B  B-offset  \
# 0              58    von Sanders        46    False  Faik Pasha        49
# 1              53    Jeff Jensen        37     True    Lindelof        46
# 2              59  Roger de Flor         9    False  Michael IX        17
# 3             115           Yang        91    False         Wei       119
# 4              62        Schenck        51    False   Roosevelt        59
#
#    B-coref                                                URL
# 0     True            http://en.wikipedia.org/wiki/Faik_Pasha
# 1    False   http://en.wikipedia.org/wiki/Tomorrowland_(film)
# 2     True  http://en.wikipedia.org/wiki/Michael_IX_Palaio...
# 3    False             http://en.wikipedia.org/wiki/Wei_Zheng
# 4     True       http://en.wikipedia.org/wiki/James_Roosevelt

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def word_offsets_to_char_offsets(text, word_offsets):
    doc = nlp(text)
    char_offsets = []
    current_offset = 0

    for token in doc:
        if token.i in word_offsets:
            start_char_offset = current_offset
            end_char_offset = current_offset + len(token.text)
            char_offsets.append((start_char_offset, end_char_offset))

        current_offset += len(token.text_with_ws)

    return char_offsets

# %%
""""
# example: 
text = df.loc[1, 'Text']
word_offsets = [df.loc[1, 'A-offset']]

char_offsets = word_offsets_to_char_offsets(text, word_offsets)
print(char_offsets)

for offset in char_offsets:
    print("Start:", offset[0], "End:", offset[1])
    
print(text[offset[0]:offset[1]])

start_offset = offset[0]
start_offset
"""
# Out:
# [(199, 203)]
# Start: 199 End: 203
# Jeff
# 199

# %%
new_A_offsets_start = []
new_A_offsets_end = []

for index, row in df.iterrows():
    
    text = df.loc[index, 'Text']
    word_offsets = [df.loc[index, 'A-offset']]

    char_offsets = word_offsets_to_char_offsets(text, word_offsets)
    
    for offset in char_offsets:
        start_offset = offset[0]
        end_offset = offset[1]
        new_A_offsets_start.append(start_offset)
        new_A_offsets_end.append(end_offset)
        
df['A_offset_start'] = new_A_offsets_start
    
    
df['A_offset_end'] = new_A_offsets_end

# %%
new_B_offsets_start = []
new_B_offsets_end = []

for index, row in df.iterrows():
    
    text = df.loc[index, 'Text']
    word_offsets = [df.loc[index, 'B-offset']]

    char_offsets = word_offsets_to_char_offsets(text, word_offsets)
    
    for offset in char_offsets:
        start_offset = offset[0]
        end_offset = offset[1]
        new_B_offsets_start.append(start_offset)
        new_B_offsets_end.append(end_offset)
        
df['B_offset_start'] = new_B_offsets_start
    
    
df['B_offset_end'] = new_B_offsets_end

# %%
new_pron_offsets_start = []
new_pron_offsets_end = []

for index, row in df.iterrows():
    
    text = df.loc[index, 'Text']
    word_offsets = [df.loc[index, 'Pronoun-offset']]

    char_offsets = word_offsets_to_char_offsets(text, word_offsets)
    
    for offset in char_offsets:
        start_offset = offset[0]
        end_offset = offset[1]
        new_pron_offsets_start.append(start_offset)
        new_pron_offsets_end.append(end_offset)
        
df['PRON_offset_start'] = new_pron_offsets_start
    
    
df['PRON_offset_end'] = new_pron_offsets_end

# %%
df.head()
# Out:
#                 ID                                               Text Pronoun  \
# 0     validation-7  Lieutenant General Weber Pasha wanted Faik Pas...      He
# 1         test-245  The project was greenlit by Walt Disney Pictur...      he
# 2  development-478  After successfully organizing the murder of th...      He
# 3         test-406  In 617, the secretary general of Wuyang Comman...      he
# 4         test-903  Roosevelt also produced the film Pot o' Gold a...     his
#
#    Pronoun-offset              A  A-offset  A-coref           B  B-offset  \
# 0              58    von Sanders        46    False  Faik Pasha        49
# 1              53    Jeff Jensen        37     True    Lindelof        46
# 2              59  Roger de Flor         9    False  Michael IX        17
# 3             115           Yang        91    False         Wei       119
# 4              62        Schenck        51    False   Roosevelt        59
#
#    B-coref                                                URL  A_offset_start  \
# 0     True            http://en.wikipedia.org/wiki/Faik_Pasha             231
# 1    False   http://en.wikipedia.org/wiki/Tomorrowland_(film)             199
# 2     True  http://en.wikipedia.org/wiki/Michael_IX_Palaio...              66
# 3    False             http://en.wikipedia.org/wiki/Wei_Zheng             411
# 4     True       http://en.wikipedia.org/wiki/James_Roosevelt             284
#
#    A_offset_end  B_offset_start  B_offset_end  PRON_offset_start  \
# 0           234             253           257                294
# 1           203             253           261                291
# 2            71             102           109                321
# 3           415             516           519                498
# 4           291             327           336                353
#
#    PRON_offset_end
# 0              296
# 1              293
# 2              323
# 3              500
# 4              356

# %%
final_df = df[['ID', 'Text', 'Pronoun', 'PRON_offset_start', 'PRON_offset_end', 'A', 'A_offset_start', 'A_offset_end', 'A-coref', 'B', 'B_offset_start', 'B_offset_end', 'B-coref', 'URL']]

# %%
final_df.head()
# Out:
#                 ID                                               Text Pronoun  \
# 0     validation-7  Lieutenant General Weber Pasha wanted Faik Pas...      He
# 1         test-245  The project was greenlit by Walt Disney Pictur...      he
# 2  development-478  After successfully organizing the murder of th...      He
# 3         test-406  In 617, the secretary general of Wuyang Comman...      he
# 4         test-903  Roosevelt also produced the film Pot o' Gold a...     his
#
#    PRON_offset_start  PRON_offset_end              A  A_offset_start  \
# 0                294              296    von Sanders             231
# 1                291              293    Jeff Jensen             199
# 2                321              323  Roger de Flor              66
# 3                498              500           Yang             411
# 4                353              356        Schenck             284
#
#    A_offset_end  A-coref           B  B_offset_start  B_offset_end  B-coref  \
# 0           234    False  Faik Pasha             253           257     True
# 1           203     True    Lindelof             253           261    False
# 2            71    False  Michael IX             102           109     True
# 3           415    False         Wei             516           519    False
# 4           291    False   Roosevelt             327           336     True
#
#                                                  URL
# 0            http://en.wikipedia.org/wiki/Faik_Pasha
# 1   http://en.wikipedia.org/wiki/Tomorrowland_(film)
# 2  http://en.wikipedia.org/wiki/Michael_IX_Palaio...
# 3             http://en.wikipedia.org/wiki/Wei_Zheng
# 4       http://en.wikipedia.org/wiki/James_Roosevelt

# %%
new_column_names = {'PRON_offset_start': 'Pronoun-start', 'PRON_offset_end': 'Pronoun-end', 'A_offset_start': 'A-start', 'A_offset_end':'A-end', 'B_offset_start' : 'B-start', 'B_offset_end':'B-end'}
final_df.rename(columns=new_column_names, inplace=True)
# Out:
# /var/folders/sg/84w6v9m54ml60m2z_k9s0dh80000gn/T/ipykernel_29275/1444219465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns=new_column_names, inplace=True)

# %%
final_df.head()
# Out:
#                 ID                                               Text Pronoun  \
# 0     validation-7  Lieutenant General Weber Pasha wanted Faik Pas...      He
# 1         test-245  The project was greenlit by Walt Disney Pictur...      he
# 2  development-478  After successfully organizing the murder of th...      He
# 3         test-406  In 617, the secretary general of Wuyang Comman...      he
# 4         test-903  Roosevelt also produced the film Pot o' Gold a...     his
#
#    Pronoun-start  Pronoun-end              A  A-start  A-end  A-coref  \
# 0            294          296    von Sanders      231    234    False
# 1            291          293    Jeff Jensen      199    203     True
# 2            321          323  Roger de Flor       66     71    False
# 3            498          500           Yang      411    415    False
# 4            353          356        Schenck      284    291    False
#
#             B  B-start  B-end  B-coref  \
# 0  Faik Pasha      253    257     True
# 1    Lindelof      253    261    False
# 2  Michael IX      102    109     True
# 3         Wei      516    519    False
# 4   Roosevelt      327    336     True
#
#                                                  URL
# 0            http://en.wikipedia.org/wiki/Faik_Pasha
# 1   http://en.wikipedia.org/wiki/Tomorrowland_(film)
# 2  http://en.wikipedia.org/wiki/Michael_IX_Palaio...
# 3             http://en.wikipedia.org/wiki/Wei_Zheng
# 4       http://en.wikipedia.org/wiki/James_Roosevelt

# %%
i = 1
a1 = final_df.loc[i, 'Pronoun-start']
a2 = final_df.loc[i, 'Pronoun-end']

text = df.loc[i, 'Text']
text[a1:a2]
# Out:
# 'he'

# %%
finalfinal_df = final_df[['ID', 'Text', 'Pronoun', 'Pronoun-start', 'A', 'A-start', 'A-coref', 'B', 'B-start', 'B-coref', 'URL']]

# %%
finalfinal_df.head()
# Out:
#                 ID                                               Text Pronoun  \
# 0     validation-7  Lieutenant General Weber Pasha wanted Faik Pas...      He
# 1         test-245  The project was greenlit by Walt Disney Pictur...      he
# 2  development-478  After successfully organizing the murder of th...      He
# 3         test-406  In 617, the secretary general of Wuyang Comman...      he
# 4         test-903  Roosevelt also produced the film Pot o' Gold a...     his
#
#    Pronoun-start              A  A-start  A-coref           B  B-start  \
# 0            294    von Sanders      231    False  Faik Pasha      253
# 1            291    Jeff Jensen      199     True    Lindelof      253
# 2            321  Roger de Flor       66    False  Michael IX      102
# 3            498           Yang      411    False         Wei      516
# 4            353        Schenck      284    False   Roosevelt      327
#
#    B-coref                                                URL
# 0     True            http://en.wikipedia.org/wiki/Faik_Pasha
# 1    False   http://en.wikipedia.org/wiki/Tomorrowland_(film)
# 2     True  http://en.wikipedia.org/wiki/Michael_IX_Palaio...
# 3    False             http://en.wikipedia.org/wiki/Wei_Zheng
# 4     True       http://en.wikipedia.org/wiki/James_Roosevelt

# %%
finalfinal_df.to_csv('MASC_balanced_data.csv', index=False)
