# %%
# %pip install fastcoref
# Out:
# Requirement already satisfied: fastcoref in /usr/local/lib/python3.10/dist-packages (2.1.6)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (4.66.2)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (1.25.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (1.11.4)
# Requirement already satisfied: spacy>=3.0.6 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (3.7.4)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (2.2.1+cu121)
# Requirement already satisfied: transformers>=4.11.3 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (4.38.2)
# Requirement already satisfied: datasets>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from fastcoref) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.5.2->fastcoref) (6.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6->fastcoref) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->fastcoref) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->fastcoref) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->fastcoref) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->fastcoref) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->fastcoref) (0.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.5.2->fastcoref) (4.0.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6->fastcoref) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6->fastcoref) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.5.2->fastcoref) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.0.6->fastcoref) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.0.6->fastcoref) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=3.0.6->fastcoref) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.0.6->fastcoref) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.0.6->fastcoref) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.5.2->fastcoref) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.5.2->fastcoref) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->fastcoref) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.5.2->fastcoref) (1.16.0)

# %%
from fastcoref import FCoref

def resolve_coreferences(text):
    model = FCoref(device='cpu')  # or 'cpu' for CPU-only execution

    preds = model.predict(texts=[text])
    clusters_as_indexes = preds[0].get_clusters(as_strings=False)
    clusters_as_strings = preds[0].get_clusters()

    return clusters_as_indexes, clusters_as_strings


# Example usage:
# text = 'We are so happy to see you using our coref package. This package is very fast!'
text = "John and Mary are good friends. He likes her company. They often go out together."
clusters_indexes, clusters_strings = resolve_coreferences(text)

print("Clusters as indexes:")
print(clusters_indexes)

print("\nClusters as strings:")
print(clusters_strings)
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# Clusters as indexes:
# [[(0, 4), (32, 34)], [(9, 13), (41, 44)]]
#
# Clusters as strings:
# [['John', 'He'], ['Mary', 'her']]

# %%
import pandas as pd
file_path = 'mini_test.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#       ID                                               Text Pronoun  \
# 0  neu-0  They originally trained as an occupational the...   their
# 1  neu-1  Since May 2011 , they have written a biweekly ...    They
# 2  neu-2  They advocated treating offenders like the men...   their
# 3  neu-3  At age 17 , Rinker moved to Seattle and worked...   their
# 4  neu-4  They wintered in 1836 - 1837 at New Orleans , ...    they
#
#    Pronoun-offset               A  A-offset  A-coref                    B  \
# 0             436    Holly Kenyon       336     True          Jane Alison
# 1             291         Postrel       206     True          Sally Satel
# 2             352  Karl Menninger       366     True         Thomas Szasz
# 3             280          Rinker       215    False               Bailey
# 4             340         Stewart       273     True  Alfred Jacob Miller
#
#    B-offset  B-coref                                                URL
# 0       410    False          http://en.wikipedia.org/wiki/Holly_Kenyon
# 1       277    False      http://en.wikipedia.org/wiki/Virginia_Postrel
# 2       399    False        http://en.wikipedia.org/wiki/Karl_Menninger
# 3       318     True        http://en.wikipedia.org/wiki/Mildred_Bailey
# 4       313    False  http://en.wikipedia.org/wiki/William_Drummond_...

# %%
def flatten(internal_list):
    flattened_list = []
    for item in internal_list:
        if isinstance(item, list):
            flattened_list.extend(item)
        else:
            flattened_list.append(item)
    return tuple(flattened_list)

# %%
def get_antecedents(index):
  offset_pron = df.loc[index, 'Pronoun-offset']
  A_coref = df.loc[index, 'A-coref']
  B_coref = df.loc[index, 'B-coref']

  true_antecedent = None
  false_antecedent_A = None
  false_antecedent_B = None


  if A_coref == True:
    true_antecedent = df.loc[index, 'A-offset']
  elif B_coref == True:
    true_antecedent = df.loc[index, 'B-offset']
  else:
    true_antecedent = None

  if A_coref == False:
    false_antecedent_A = df.loc[index, 'A-offset']

  if B_coref == False:
    false_antecedent_B = df.loc[index, 'B-offset']

  false_antecedents = [antecedent for antecedent in [false_antecedent_A, false_antecedent_B] if antecedent is not None]

  gold_cluster = (true_antecedent, offset_pron)
  false = (false_antecedents, offset_pron)

  false_cluster = flatten(false)

  return gold_cluster, false_cluster

# %%
for index, row in df.iterrows():
  gold_cluster, false_cluster = get_antecedents(index)
  print('gold')
  print(gold_cluster)
  print('false')
  print(false_cluster)
# Out:
# gold
# (336, 436)
# false
# (410, 436)
# gold
# (206, 291)
# false
# (277, 291)
# gold
# (366, 352)
# false
# (399, 352)
# gold
# (318, 280)
# false
# (215, 280)
# gold
# (273, 340)
# false
# (313, 340)

# %%
"""
# test
pred_offset = [[17, 74, 168, 206, 291], [94, 142], [214, 311, 344]]
gold_cluster_true = (206, 291)
gold_cluster_false = (214, 311)
"""

def calc_TP_FN_FP(preds, gold_cluster_true, gold_cluster_false):

  TP = 0
  FN = 0
  for sublist in preds:
      if all(value in sublist for value in gold_cluster_true):
          # Increment TP by 1 if both items in gold_cluster_true are present in any cluster
          TP += 1
          break
  else:
      # increment FN if none of the sublists contain both values from gold_cluster_true
      FN += 1

  FP = 0
  for sublist in preds:
      if all(value in sublist for value in gold_cluster_false):
          # Increment FP by 1 if both items in gold_cluster_false are present in any cluster
          FP += 1
          break

  return TP, FN, FP

# %%
"""
# test
gold_cluster_true, gold_cluster_false = get_antecedents(2)

text = df.loc[2, 'Text']
pred_clusters_indexes, pred_clusters_strings = resolve_coreferences(text)
preds = [[tup[0] for tup in sublist] for sublist in pred_clusters_indexes]


TP, FN, FP = calc_TP_FN_FP(preds, gold_cluster_true, gold_cluster_false)
print(TP, FN, FP)
"""
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 1 0
# GOLD CLUSTER:
# (366, 352)
# FALSE CLUSTER
# (399, 352)
# Clusters as indexes:
# [[0, 58, 296, 352], [163, 366]]
#
# Clusters as strings:
# [['They', 'Their', 'them', 'their'], ['Menninger', 'Karl Menninger']]

# %%
def calc_prec_recall(TP, FN, FP):

  precision = TP / (TP + FP)
  recall = TP / (TP + FN)

  f1_score = 2 * (precision * recall) / (precision + recall)

  return precision, recall, f1_score

# %%
true_pos = []
false_neg = []
false_pos = []


for index, row in df.iterrows():
  gold_cluster_true, gold_cluster_false = get_antecedents(index)

  text = df.loc[index, 'Text']
  pred_clusters_indexes, pred_clusters_strings = resolve_coreferences(text)
  preds = [[tup[0] for tup in sublist] for sublist in pred_clusters_indexes]
  TP, FN, FP = calc_TP_FN_FP(preds, gold_cluster_true, gold_cluster_false)

  true_pos.append(TP)
  false_neg.append(FN)
  false_pos.append(FP)

total_TP = sum(true_pos)
total_FN = sum(false_neg)
total_FP = sum(false_pos)
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prec, recall, f1 = calc_prec_recall(total_TP, total_FN, total_FP)
print(f'precision: {prec}')
print(f'recall: {recall}')
print(f'f1: {f1}')
# Out:
# precision: 1.0
# recall: 0.2
# f1: 0.33333333333333337
